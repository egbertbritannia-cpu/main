# %% [markdown]
# <a href="https://colab.research.google.com/github/egbertbritannia-cpu/main/blob/main/requirements_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROBABILITY & STATISTICS **

# %% [markdown]
# # IMPORT CÁC THƯ VIỆN (LIBRARY)

# %%
# Import và ký hiệu lại tên thư viện
import numpy as np # dùng tính toán thống kê
import pandas as pd # dùng tính toán thống kê
import statsmodels.api as sm # dùng chạy mô hình thống kê
import matplotlib.pyplot as plt # vẽ đồ thị

# %% [markdown]
# # IMPORT DATA

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/egbertbritannia-cpu/main/refs/heads/main/education_career_success.csv'
df = pd.read_csv(url)
print('In 10 dòng đầu tiên ')
df.head(10)
# print(df[['Soft_Skills_Score', 'Networking_Score']].corr())
# print(df[['Soft_Skills_Score', 'Networking_Score']].head(20))
# Out:
# In 10 dòng đầu tiên
#   Student_ID  Age  Gender  High_School_GPA  SAT_Score  University_GPA  \
# 0       S001   22    Male              3.8       1450             3.6
# 1       S002   24  Female              3.6       1380             3.4
# 2       S003   21    Male              3.9       1520             3.8
# 3       S004   23  Female              3.5       1300             3.2
# 4       S005   25    Male              3.7       1420             3.5
# 5       S006   22  Female              3.4       1250             3.1
# 6       S007   24    Male              3.2       1180             2.9
# 7       S008   23  Female              3.8       1480             3.7
# 8       S009   21    Male              3.6       1350             3.3
# 9       S010   25  Female              3.9       1550             3.9
#
#      Field_of_Study  Internships_Completed  Projects_Completed  \
# 0  Computer Science                      3                   7
# ...
